# %% [markdown]
# # Data Science Day 11

# %% [markdown]
# ## What is Matplotlib?

# %% [markdown]
# - To make necessary statistical inferences, it becomes necessary to visualize your data and Matplotlib is one such solution for Python users
# - It is a very powerful plotting library useful for those working with Python and NumPy
# - The most used module of Matplotlib is Pyplot which provides an interface like MATLAB but instead, it uses Python and it is open source

# %% [markdown]
# ### Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.2.2'

# %% [markdown]
# - The plt interface is what we will use most often
# - Pyplot is a module of Matplotlib which provides simple functions to add plot elements like lines, images, text, etc. to the current axes in the current figure

# %% [markdown]
# ### General Concepts

# %% [markdown]
# - A Matplotlib figure can be categorized into several parts:
#     - Figure: it is a whole figure which may contain one or more than one axes (plots)
#         - You can think of a Figure as a canvas which contains plots
#     - Axes: it is what we generally think of as a plot
#         - A Figure can contain many Axes
#         - It contains two or three (in the case of 3D) Axes objects
#         - Each Axes has a title, an x-label and a y-label
#     - Axis: they are the number line like objects and take care of generating the graph limits
#     - Artist: everything which one can see on the figure is an artist like Text Objects, Line2D objects, collection objects
#         - Most Artists are tied to Axes

# %%
import numpy as np

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %% [markdown]
# - We pass two arrays as our input arguments to Pyplot's plot() method and use show() method to invoke the required plot
# - Note that the first array appear on the x-axis and second array appears on the y-axis of the plot

# %% [markdown]
# ### show() or No show()? How to Display Your Plots

# %% [markdown]
# - A visualization you can't see won't be of much use, but just how you ivew your Matplotlib plots depends on the context

# %%
x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %% [markdown]
# - The plt.show() command does a lot under the hood, as it must interact with your system's interactive graphical backend
# - The details of this operation can vary greatly from system to system and even installation to installation, but matplotlib does its best to hide all these details from you
# - One thing to be aware of the plt.show() command should be used only once per Python session, and is most often seen at the very end of the script
# - Multiple show() commands can lead to unpredictable backend-dependent behavior, and should mostly be avoided

# %% [markdown]
# ### Plotting in Jupyter Notebook

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %% [markdown]
# ### Saving Figures to File

# %% [markdown]
# - One nice feature of Matplotlib is the ability to save figures in a wide variety of formats
# - Saving a figure can be done using the savefig() command
# - For example, to save the previous figure as a PNG file:

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# - We now have a file called my_figure.png in the current working directory
# - To confirm that it contains what we think it contains, we can use the IPython Image object to display the file contents

# %%
from IPython.display import Image
Image('my_figure.png')

# %% [markdown]
# - In savefig(), the file format is inferred from the extension of the given filename

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ### Back to Making our First Plot

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.title("First Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
plt.figure(figsize=(15,5))
plt.plot([1,2,3,4],[1,4,9,16])
plt.title("First Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
plt.plot([1,2,3,4],[1,4,9,16],"go")
plt.title("First Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# ## Simple Line Plots

# %%
#%matplotlib inline
#import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
#import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))

# %% [markdown]
# ## Two Interfaces for the Price of One

# %% [markdown]
# ### MATLAB-style Interface

# %%
plt.figure() #create a plot figure

#create the first of two panels and set current axis
plt.subplot(2, 1, 1) #(rows, columns, panel number)
plt.plot(x, np.sin(x))

#create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# ### Object-oriented Interface

# %%
#first create a grid of plots
#ax will be an array of the two Axes objects
fig, ax = plt.subplots(2)

#call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# ### Adjusting the Plot: Line Colors and Styles

# %%
plt.plot(x, np.sin(x-0), color='blue') #specify color by name
plt.plot(x, np.sin(x-1), color='g') #short color code (rgbcmyk)
plt.plot(x, np.sin(x-2), color='0.75') #Grayscale between 0 and 1
plt.plot(x, np.sin(x-3), color='#FFDD44') #Hex code (RRGGBB from 00 to FF)

# %%
plt.plot(x, x+0, linestyle='solid')
plt.plot(x, x+1, linestyle='dashed')
plt.plot(x, x+2, linestyle='dashdot')
plt.plot(x, x+3, linestyle='dotted')

#for short, you can use the following codes
plt.plot(x, x+4, linestyle='-')
plt.plot(x, x+5, linestyle='--')
plt.plot(x, x+6, linestyle='-.')

# %%
plt.plot(x, x+0, '-g')

# %% [markdown]
# ### Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend()

# %% [markdown]
# ## Simple Scatterplots

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='blue')

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x, y, '-ok')

# %%
plt.plot(x, y, '-p', color='red', markersize=15,
        linewidth=4, markerfacecolor='white',
        markeredgecolor='gray', markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ### Scatterplots with plt.scatter

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.4,
           cmap='viridis')
plt.colorbar()

# %% [markdown]
# ## Visualizing Errors

# %% [markdown]
# ### Basic Errorbars

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
            ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Density and Contour Plots

# %% [markdown]
# ### Visualizing a Three-Dimensional Function

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='blue')

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy')

# %%
plt.cm?

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
          cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image')
# Out:
# <ipython-input-57-573141568f48>:4: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   plt.axis(aspect='image')
# (0.0, 5.0, 0.0, 5.0)

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
          cmap='RdGy', alpha=0.5)
plt.colorbar()

# %% [markdown]
# ## Histograms, Binnings, and Density

# %%
data = np.random.randn(100)
plt.hist(data)
# Out:
# (array([ 1.,  6.,  6.,  6., 20., 23., 18., 13.,  3.,  4.]),
#  array([-2.89578162, -2.37972307, -1.86366452, -1.34760598, -0.83154743,
#         -0.31548888,  0.20056967,  0.71662822,  1.23268677,  1.74874532,
#          2.26480386]),
#  <a list of 10 Patch objects>)
